# %%
from afe.benchmark import compare, BaselineMethod

def openfe(X_train, y_train, X_test, task):
    from openfe import OpenFE, transform
    feats = OpenFE().fit(data=X_train, label=y_train, task=task, n_jobs=1, verbose=False)
    return transform(X_train, X_test, feats[:10], n_jobs=1)

result = compare(
    methods=[BaselineMethod, openfe],
    datasets=["german-credit", "concrete-strength"],   # built-in suite keys
)
# Out:
# 100%|██████████| 4/4 [00:25<00:00,  6.32s/it]
# 100%|██████████| 4/4 [00:15<00:00,  3.87s/it]
# 100%|██████████| 4/4 [00:03<00:00,  1.09it/s]
# 100%|██████████| 4/4 [00:02<00:00,  1.98it/s]
# 100%|██████████| 4/4 [00:02<00:00,  1.61it/s]
# 100%|██████████| 4/4 [00:00<00:00,  6.15it/s]

# %%
df = result.to_frame() # raw rows as a pandas DataFrame

# %%
df
# Out:
#                   key    method            task status  gen_elapsed_s  \
# 0       german-credit  baseline  classification     ok       0.000410
# 1       german-credit  baseline  classification     ok       0.000410
# 2       german-credit  baseline  classification     ok       0.000410
# 3       german-credit    openfe  classification     ok      46.921936
# 4       german-credit    openfe  classification     ok      46.921936
# 5       german-credit    openfe  classification     ok      46.921936
# 6   concrete-strength  baseline      regression     ok       0.000511
# 7   concrete-strength  baseline      regression     ok       0.000511
# 8   concrete-strength  baseline      regression     ok       0.000511
# 9   concrete-strength    openfe      regression     ok       7.419944
# 10  concrete-strength    openfe      regression     ok       7.419944
# 11  concrete-strength    openfe      regression     ok       7.419944
#
#     feature_efficiency model_family  n_features_generated  n_features_final  \
# 0                  NaN         tree                     0                20
# 1                  NaN       linear                     0                20
# 2                  NaN          knn                     0                20
# 3                  0.7         tree                    10                30
# 4                  0.7       linear                    10                30
# 5                  0.7          knn                    10                30
# 6                  NaN         tree                     0                 8
# 7                  NaN       linear                     0                 8
# 8                  NaN          knn                     0                 8
# 9                  1.0         tree                    10                18
# 10                 1.0       linear                    10                18
# 11                 1.0          knn                    10                18
#
#    metric     value       mae
# 0     auc  0.828690       NaN
# 1     auc  0.814643       NaN
# 2     auc  0.780417       NaN
# 3     auc  0.831190       NaN
# 4     auc  0.821667       NaN
# 5     auc  0.775774       NaN
# 6      r2  0.935087  2.983895
# 7      r2  0.647403  8.014788
# 8      r2  0.715596  6.952888
# 9      r2  0.935898  3.024582
# 10     r2  0.788663  5.991209
# 11     r2  0.818003  5.317801
